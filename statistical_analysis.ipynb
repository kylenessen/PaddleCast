# %% [markdown]
# # Statistical Analysis
#
# This notebook conducts statistical analysis on data loaded from Google Sheets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from data_loader import load_google_sheet_data

# %% [markdown]
# ## Load Data from Google Sheets

# %%
# Load your data
SHEET_URL = "https://docs.google.com/spreadsheets/d/1EX83SL2E6Cg_Y1y88e8svOvqS6SjZd11rIKaeX_3ABs/edit?gid=0#gid=0"

# Load the data
df = load_google_sheet_data(SHEET_URL)

if df is not None:
    print("Data loaded successfully!")
    print(f"Shape: {df.shape}")
    print("\nFirst few rows:")
    display(df.head())
    print("\nData types:")
    print(df.dtypes)
else:
    print("Failed to load data. Please check your sheet URL and make sure it's public.")
# Out:
# Data loaded successfully!
# Shape: (31, 7)
#
# First few rows:
#                      submittedAt  score       conditions waterConditions  \
# 0  2025-08-13T19:37:49.555-07:00  🌕🌕🌕🌕🌗  ⛅ Partly Cloudy     🌬️ Textured
# 1  2025-08-14T07:03:44.798-07:00    🌕🌕🌗     🌫️ Light Fog       💧 Rippled
# 2  2025-08-14T14:38:17.950-07:00    🌕🌕🌕   🌫️🌫️ Dense Fog       💧 Rippled
# 3  2025-08-14T18:44:39.804-07:00    🌕🌕🌗    🌫️⬆️ High Fog        🌊 Choppy
# 4  2025-08-15T10:48:22.226-07:00   🌕🌕🌕🌕        ☁️ Cloudy       💧 Rippled
#
#       visibility                                              notes  \
# 0        👀✅ Good                                       Great sunset
# 1  👀➖ Acceptable                                     Wet and dreary
# 2        👀❌ Poor                   At the rock for this observation
# 3        👀✅ Good  The more emily and I look at the water, the mo...
# 4        👀✅ Good                               Grey, but looks calm
#
#      formMode
# 0  production
# 1  production
# 2  production
# 3  production
# 4  production
# Data types:
# submittedAt        object
# score              object
# conditions         object
# waterConditions    object
# visibility         object
# notes              object
# formMode           object
# dtype: object

# %% [markdown]
# ## Data Exploration and Analysis

# %%
# Basic data exploration
if 'df' in locals() and df is not None:
    print("Dataset Overview:")
    print(f"Rows: {len(df)}")
    print(f"Columns: {len(df.columns)}")
    print(f"\nColumn names: {list(df.columns)}")
    
    print("\nMissing values:")
    print(df.isnull().sum())
    
    print("\nBasic statistics:")
    display(df.describe())
# Out:
# Dataset Overview:
# Rows: 31
# Columns: 7
#
# Column names: ['submittedAt', 'score', 'conditions', 'waterConditions', 'visibility', 'notes', 'formMode']
#
# Missing values:
# submittedAt         0
# score               0
# conditions          0
# waterConditions     0
# visibility          0
# notes              21
# formMode            0
# dtype: int64
#
# Basic statistics:
#                           submittedAt score conditions waterConditions  \
# count                              31    31         31              31
# unique                             31     7          6               6
# top     2025-08-13T19:37:49.555-07:00  🌕🌕🌕🌕   ☀️ Sunny       💧 Rippled
# freq                                1    11         16              12
#
#        visibility         notes    formMode
# count          31            10          31
# unique          3            10           1
# top       👀✅ Good  Great sunset  production
# freq           19             1          31

# %%
# Add your statistical analysis here
# Example: correlation analysis, hypothesis testing, etc.

# %%
df
# Out:
#                       submittedAt  score       conditions waterConditions  \
# 0   2025-08-13T19:37:49.555-07:00  🌕🌕🌕🌕🌗  ⛅ Partly Cloudy     🌬️ Textured
# 1   2025-08-14T07:03:44.798-07:00    🌕🌕🌗     🌫️ Light Fog       💧 Rippled
# 2   2025-08-14T14:38:17.950-07:00    🌕🌕🌕   🌫️🌫️ Dense Fog       💧 Rippled
# 3   2025-08-14T18:44:39.804-07:00    🌕🌕🌗    🌫️⬆️ High Fog        🌊 Choppy
# 4   2025-08-15T10:48:22.226-07:00   🌕🌕🌕🌕        ☁️ Cloudy       💧 Rippled
# 5   2025-08-15T13:21:24.190-07:00    🌕🌕🌗         ☀️ Sunny    ⚠️ Whitecaps
# 6   2025-08-16T14:17:17.471-07:00    🌕🌕🌗   🌫️🌫️ Dense Fog         ❓ Other
# 7   2025-08-17T10:10:13.684-07:00   🌕🌕🌕🌕         ☀️ Sunny     🌬️ Textured
# 8   2025-08-17T17:57:42.169-07:00     🌕🌕        ☁️ Cloudy        🌊 Choppy
# 9   2025-08-18T09:49:04.077-07:00   🌕🌕🌕🌕         ☀️ Sunny     🌬️ Textured
# 10  2025-08-19T08:26:01.308-07:00  🌕🌕🌕🌕🌕         ☀️ Sunny         🪞 Glass
# 11  2025-08-19T15:40:37.044-07:00   🌕🌕🌕🌗  ⛅ Partly Cloudy     🌬️ Textured
# 12  2025-08-20T09:18:43.314-07:00   🌕🌕🌕🌕         ☀️ Sunny     🌬️ Textured
# 13  2025-08-21T11:55:17.344-07:00  🌕🌕🌕🌕🌗         ☀️ Sunny       💧 Rippled
# 14  2025-08-21T14:43:27.458-07:00   🌕🌕🌕🌗         ☀️ Sunny        🌊 Choppy
# 15  2025-08-21T19:34:35.665-07:00   🌕🌕🌕🌕         ☀️ Sunny     🌬️ Textured
# 16  2025-08-22T09:54:02.326-07:00    🌕🌕🌕   🌫️🌫️ Dense Fog       💧 Rippled
# 17  2025-08-22T18:42:32.864-07:00    🌕🌕🌗   🌫️🌫️ Dense Fog       💧 Rippled
# 18  2025-08-24T09:34:19.568-07:00   🌕🌕🌕🌗         ☀️ Sunny     🌬️ Textured
# 19  2025-08-24T19:05:45.810-07:00   🌕🌕🌕🌕         ☀️ Sunny     🌬️ Textured
# 20  2025-08-25T09:10:02.638-07:00   🌕🌕🌕🌕     🌫️ Light Fog       💧 Rippled
# 21  2025-08-25T17:59:36.928-07:00  🌕🌕🌕🌕🌗         ☀️ Sunny     🌬️ Textured
# 22  2025-08-26T08:59:38.423-07:00   🌕🌕🌕🌕        ☁️ Cloudy         🪞 Glass
# 23  2025-08-26T17:21:25.964-07:00  🌕🌕🌕🌕🌗         ☀️ Sunny       💧 Rippled
# 24  2025-08-27T09:26:06.331-07:00   🌕🌕🌕🌕         ☀️ Sunny     🌬️ Textured
# 25  2025-08-28T07:15:40.267-07:00  🌕🌕🌕🌕🌗         ☀️ Sunny       💧 Rippled
# 26  2025-09-02T19:21:17.349-07:00  🌕🌕🌕🌕🌗         ☀️ Sunny       💧 Rippled
# 27  2025-09-04T07:19:02.680-07:00   🌕🌕🌕🌕    🌫️⬆️ High Fog       💧 Rippled
# 28  2025-09-05T09:50:39.723-07:00   🌕🌕🌕🌕        ☁️ Cloudy     🌬️ Textured
# 29  2025-09-05T18:00:56.388-07:00    🌕🌕🌗        ☁️ Cloudy        🌊 Choppy
# 30  2025-09-06T19:37:05.813-07:00  🌕🌕🌕🌕🌕         ☀️ Sunny       💧 Rippled
#
#        visibility                                              notes  \
# 0         👀✅ Good                                       Great sunset
# 1   👀➖ Acceptable                                     Wet and dreary
# 2         👀❌ Poor                   At the rock for this observation
# 3         👀✅ Good  The more emily and I look at the water, the mo...
# 4         👀✅ Good                               Grey, but looks calm
# 5         👀✅ Good  Really nice day except for the wind. White cap...
# 6         👀❌ Poor                                                NaN
# 7         👀✅ Good                                        Looks nice!
# 8   👀➖ Acceptable                                                NaN
# 9         👀✅ Good                                                NaN
# 10        👀✅ Good                                    So nice. “Gahh”
# 11  👀➖ Acceptable                                                NaN
# 12        👀✅ Good                                                NaN
# 13        👀✅ Good                                                NaN
# 14        👀✅ Good       Actual paddle. Pretty good but fighting wind
# 15        👀✅ Good                                                NaN
# 16        👀❌ Poor                                                NaN
# 17        👀❌ Poor                                                NaN
# 18        👀✅ Good                                                NaN
# 19        👀✅ Good                                                NaN
# 20        👀❌ Poor                                                NaN
# 21        👀✅ Good                                                NaN
# 22  👀➖ Acceptable                                                NaN
# 23        👀✅ Good                                                NaN
# 24        👀✅ Good                                                NaN
# 25        👀✅ Good                                                NaN
# 26        👀✅ Good                                                NaN
# 27  👀➖ Acceptable                                                NaN
# 28  👀➖ Acceptable                                                NaN
# 29  👀➖ Acceptable                                                NaN
# 30        👀✅ Good                           Beautiful with full moon
#
#       formMode
# 0   production
# 1   production
# 2   production
# 3   production
# 4   production
# 5   production
# 6   production
# 7   production
# 8   production
# 9   production
# 10  production
# 11  production
# 12  production
# 13  production
# 14  production
# 15  production
# 16  production
# 17  production
# 18  production
# 19  production
# 20  production
# 21  production
# 22  production
# 23  production
# 24  production
# 25  production
# 26  production
# 27  production
# 28  production
# 29  production
# 30  production
